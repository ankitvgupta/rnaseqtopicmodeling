# %% [markdown]
# # Final Project - CS 281

# %% [markdown]
# Ankit Gupta

# %% [markdown]
# ### Import Statements

# %%
import pandas as pd
import numpy as np
from scipy import stats as scistats
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from IPython.display import Image
import lda
from scipy.sparse import csr_matrix

# %matplotlib inline

# %%
from CTM import CTM
from CTMParallel import CTMParallel

# %%
from sklearn.cross_validation import train_test_split

# %%
# Remove genes that are super high in expression.
features =  pd.read_table("GSE60361_C1-3005-Expression.txt", sep='\t', usecols=range(3006)).set_index('cell_id').T
genes_of_interest = (-features.sum()).sort(inplace=False)[20:].index
remove_low_expression_genes = features.sum() > 100
genes_wanted = remove_low_expression_genes[remove_low_expression_genes].index.intersection(genes_of_interest)
#genes_of_interest = genes_of_interest & remove_low_expression_genes
features = features.ix[:, genes_wanted]

vocab = features.columns
compressed_features = csr_matrix(features)

# %%
features.shape
# Out:
# (3005, 12883)

# %%
compressed_features.shape
# Out:
# (3005, 12883)

# %%
len(set(map(lambda x: x.split('_')[0], features.index.tolist())))
# Out:
# 76

# %%
import csv
lines = []
with open("expression_mRNA_17-Aug-2014.txt", 'r') as f:
    reader = csv.reader(f, delimiter='\t')
    for line in reader:
        lines.append(line)

# %%
metadata = pd.DataFrame(lines)
metadata = metadata.set_index(0)
metadata.columns = metadata.ix['cell_id', :]
#metadata.columns = metadata.ix[7, :]
#metadata.rename(columns={'cell_id':'info'}).set_index('info')

# %%
#metadata =  pd.read_table("expression_mRNA_17-Aug-2014.txt", sep='\t', nrows=15, header=0, usecols=range(3006)).rename(columns={'tissue':'info'}).set_index('info')
#data =  pd.read_csv("expression_mRNA_17-Aug-2014.txt", sep='\t', skiprows=range(1, 11), usecols=range(3006), header=0)

# %%
classification = metadata.ix['group #', :]

# This contains the classification for each gene into 9 major classes of genes.
# We can compare the classification problem using standard SVM to that with LDA, and later with Pachinko Allocation.
classification = classification[features.index]

# %%
classification.shape
# Out:
# (3005,)

# %%
X_train, X_test, y_train, y_test = train_test_split(features, classification, train_size=500, test_size=100, random_state=42)

# %%
X_train
# Out:
# cell_id         Actg1  Cst3  Syt1  Slc25a4  Rtn1  Aldoa  Cpe  Snhg11  Mdh1  \
# 1772058177_F10     27     9     0        0     0      0    0       0     0
# 1772066107_C06     39     6    39       36    47     39   38      18    43
# 1772066070_A08     28     1    20        7    15      4   13      88     2
# 1772066074_C01     21     8    27       12    37     15   33      70    11
# 1772066077_D04     52    13    27       66    44     64   19      49    63
# 1772066096_F01     15     5    10       40    22     24   20      12    24
# 1772067066_H08     51    13   154       44   102     64   35      23    53
# 1772067073_E11      2     5     0        7     0      4    0       0     2
# 1772067094_B04      4   139     2        8     3      3   26       0     5
# 1772067057_D08     76     8    62       77    46    108   76      54   103
# 1772071014_F02     11   200     1       13     1      2  261       0    15
# 1772063063_C11      8    11    18        5     6      2    6       0     0
# 1772066070_E08     11     3    18       40    24     13   20      70     2
# 1772066110_D12      8     1     5        4     1      6    2       2    10
# 1772071014_E05     49    15    93       54    72     71   14      41    53
# 1772067093_F09     20    44    34        7    26      8   26      70     6
# 1772060224_A02      9     4     0        5     3      1    1       0     6
# 1772066077_A10     64     7   129       37   138     41  176     198    32
# 1772066076_A07      2    20     0        0     0      1    0       0     0
# 1772067054_B10     12    11    26       25    69     59   51       7    20
# 1772066077_G07     53     9    26       58    39     47   20      38    28
# 1772063063_G02      7     0     1        8     7      6    5      13     0
# 1772067083_H04      6    26     6        5     5      7    4      74     3
# 1772071015_C02      3     1     1        1     3      1    3       3     1
# 1772067073_C02      1     4     0        9     0      4    3       0     4
# 1772062128_D12     21    10    15       33    10     27   11      46    30
# 1772058148_F03      4    24     0        6     0      3    7       0     1
# 1772062116_C03     15     5     6       18     7     20    4       4    31
# 1772066101_C07     14     3    18       17    10     22   26      15    16
# 1772066076_D05     22     9    28        7    30     20   28      61    14
# ...               ...   ...   ...      ...   ...    ...  ...     ...   ...
# 1772062109_G11     11     7    24       35    13     16    5      27    55
# 1772066077_E10      3     1     4        0     4      4    0       0     0
# 1772063078_B12     46     0     9       38    21     19    8      12    55
# 1772063079_E08      7     0     5        5     4      2    0       0     0
# 1772071044_A09     52   272    42       59    55     77   72      53    24
# 1772067058_A07     26     5    24       29    39     18   42      24    12
# 1772058177_H07     33     2    45       36     7     48    9      16    62
# 1772058177_C02     63     0     1       59     0      8    1       1     5
# 1772060226_H11     22    23     0       18     0      5    0       0    35
# 1772067060_B09     49    10    25       58    74     63   39      44    55
# 1772066077_D08     23     3    30       12    14      4   40      66     4
# 1772063063_B01     60    15    20       22     6     23    3      23    14
# 1772067076_B12     22     5    34        4    35     12   53      67     6
# 1772063070_E01     24     2    13       31    21      7   23       7    21
# 1772066097_F11     36     2    29       54    17     33   47      19    37
# 1772063077_A07     46    10    53       31    25     48   31      54    65
# 1772066077_H04     16     5     0        9     0      3    0       0     3
# 1772066099_E05     14     3     1        6     0      0    2       1     2
# 1772066101_F03     13    34    65       33    14     26   13      15    54
# 1772066100_F08     14     4    42       16    17     16    6      18    41
# 1772071015_A01     28     2    75       27    38     46   15      22    42
# 1772063079_A11      2     3     2        0     0      0    0       0     2
# 1772067054_B03     60     5    28       37    38     49   31     115    12
# 1772067065_F07     21    22    45       27    52     39   26      12    33
# 1772066098_E03      7     6    16       15    11     27   24      15    24
# 1772058148_H05      8     8     1        5     0      4    3       1     6
# 1772066096_G06     11   261     1        3     2      1    5       0     0
# 1772067082_C12     32     0    18       25    23     32   46      41     7
# 1772060224_B04     14   167     0       21     6      7   35       0    18
# 1772062111_C02      3     0     0        5     1      3    0       0     2
#
# cell_id         Rps29  ...   Ccno  Bambi-ps1  Krt79  Inadl_loc1  \
# 1772058177_F10     31  ...      0          0      0           0
# 1772066107_C06     16  ...      0          0      0           0
# 1772066070_A08     15  ...      0          0      0           0
# 1772066074_C01      2  ...      0          0      0           0
# 1772066077_D04     54  ...      0          0      0           0
# 1772066096_F01     31  ...      0          0      0           0
# 1772067066_H08     11  ...      0          0      0           0
# 1772067073_E11      7  ...      0          0      0           0
# 1772067094_B04      6  ...      0          0      0           0
# 1772067057_D08     36  ...      0          0      0           0
# 1772071014_F02     14  ...      0          0      0           0
# 1772063063_C11     25  ...      0          0      0           0
# 1772066070_E08     14  ...      0          0      0           0
# 1772066110_D12      8  ...      0          0      0           0
# 1772071014_E05     16  ...      0          0      0           0
# 1772067093_F09      7  ...      0          0      0           0
# 1772060224_A02     73  ...      0          0      0           0
# 1772066077_A10      5  ...      1          0      0           0
# 1772066076_A07     69  ...      0          0      0           0
# 1772067054_B10     13  ...      0          0      0           0
# 1772066077_G07     29  ...      0          0      0           0
# 1772063063_G02     18  ...      0          0      0           0
# 1772067083_H04      1  ...      0          0      0           0
# 1772071015_C02      2  ...      0          0      0           1
# 1772067073_C02     14  ...      0          0      0           0
# 1772062128_D12     26  ...      0          0      0           0
# 1772058148_F03     11  ...      0          0      0           0
# 1772062116_C03     25  ...      0          0      0           0
# 1772066101_C07     16  ...      0          0      0           0
# 1772066076_D05      2  ...      0          0      0           0
# ...               ...  ...    ...        ...    ...         ...
# 1772062109_G11     31  ...      0          0      0           0
# 1772066077_E10     10  ...      0          0      0           0
# 1772063078_B12     26  ...      0          0      0           0
# 1772063079_E08     10  ...      0          0      0           0
# 1772071044_A09     33  ...      0          0      2           0
# 1772067058_A07     21  ...      0          0      0           0
# 1772058177_H07     51  ...      0          0      0           0
# 1772058177_C02     52  ...      0          0      0           0
# 1772060226_H11    156  ...      0          0      0           0
# 1772067060_B09     14  ...      0          0      0           1
# 1772066077_D08      4  ...      0          0      0           0
# 1772063063_B01     66  ...      0          0      0           0
# 1772067076_B12      3  ...      0          0      0           0
# 1772063070_E01     13  ...      0          0      0           0
# 1772066097_F11     32  ...      0          0      0           0
# 1772063077_A07     37  ...      0          0      0           0
# 1772066077_H04     21  ...      0          0      0           0
# 1772066099_E05     10  ...      0          0      0           0
# 1772066101_F03     22  ...      0          0      0           0
# 1772066100_F08     18  ...      0          0      0           0
# 1772071015_A01     13  ...      0          0      0           0
# 1772063079_A11     10  ...      0          0      0           0
# 1772067054_B03     13  ...      0          0      0           0
# 1772067065_F07     20  ...      0          0      0           0
# 1772066098_E03     26  ...      0          0      0           0
# 1772058148_H05     51  ...      0          0      0           0
# 1772066096_G06     56  ...      0          0      0           0
# 1772067082_C12      9  ...      0          0      0           0
# 1772060224_B04     43  ...      0          0      0           0
# 1772062111_C02     11  ...      0          0      0           0
#
# cell_id         E130201H02Rik  Dll4  Mthfd2l  Tchh  Prdx6b  Tal1
# 1772058177_F10              0     0        0     0       0     0
# 1772066107_C06              0     0        0     0       0     0
# 1772066070_A08              0     0        0     0       0     0
# 1772066074_C01              0     0        0     1       0     0
# 1772066077_D04              0     0        0     0       0     0
# 1772066096_F01              0     0        0     0       0     0
# 1772067066_H08              0     0        0     0       0     0
# 1772067073_E11              0     0        0     0       0     0
# 1772067094_B04              0     0        0     0       0     0
# 1772067057_D08              0     0        1     1       0     0
# 1772071014_F02              0     0        0     0       1     0
# 1772063063_C11              0     0        0     0       0     0
# 1772066070_E08              0     0        0     0       0     0
# 1772066110_D12              0     0        0     0       0     0
# 1772071014_E05              0     0        0     0       0     0
# 1772067093_F09              0     0        0     0       0     0
# 1772060224_A02              0     0        0     0       0     0
# 1772066077_A10              0     0        0     0       0     1
# 1772066076_A07              0     0        0     0       0     0
# 1772067054_B10              0     0        0     0       0     0
# 1772066077_G07              0     0        0     0       0     0
# 1772063063_G02              0     0        0     0       0     0
# 1772067083_H04              0     0        0     0       0     0
# 1772071015_C02              0     0        0     0       0     0
# 1772067073_C02              0     0        0     0       0     0
# 1772062128_D12              0     0        0     0       0     0
# 1772058148_F03              0     0        0     0       0     0
# 1772062116_C03              0     0        0     0       0     0
# 1772066101_C07              0     0        0     0       0     0
# 1772066076_D05              0     0        0     0       0     0
# ...                       ...   ...      ...   ...     ...   ...
# 1772062109_G11              0     0        0     0       0     0
# 1772066077_E10              0     0        0     0       0     0
# 1772063078_B12              0     0        0     0       0     0
# 1772063079_E08              0     0        0     0       0     0
# 1772071044_A09              0     0        0     0       0     2
# 1772067058_A07              0     0        0     0       0     0
# 1772058177_H07              0     0        0     0       0     0
# 1772058177_C02              0     0        0     0       0     0
# 1772060226_H11              0     3        0     0       0     0
# 1772067060_B09              0     0        1     0       0     0
# 1772066077_D08              0     0        0     0       0     0
# 1772063063_B01              0     0        0     0       0     2
# 1772067076_B12              0     0        0     2       0     0
# 1772063070_E01              0     0        0     0       0     0
# 1772066097_F11              0     0        0     0       1     0
# 1772063077_A07              0     0        0     0       0     0
# 1772066077_H04              0     0        0     0       0     0
# 1772066099_E05              0     0        0     0       0     0
# 1772066101_F03              0     0        0     0       0     0
# 1772066100_F08              0     0        0     0       0     0
# 1772071015_A01              0     0        0     0       0     0
# 1772063079_A11              0     0        0     0       0     2
# 1772067054_B03              0     0        0     0       0     0
# 1772067065_F07              0     0        0     0       0     0
# 1772066098_E03              0     0        0     0       0     0
# 1772058148_H05              0     0        0     0       0     0
# 1772066096_G06              0     0        0     0       0     0
# 1772067082_C12              0     0        0     0       0     0
# 1772060224_B04              0     0        0     0       0     0
# 1772062111_C02              0     0        0     0       0     0
#
# [500 rows x 12883 columns]

# %%
compressed_features.todense()
# Out:
# matrix([[ 3,  1,  1, ...,  0,  0,  0],
#         [43, 17, 59, ...,  0,  0,  0],
#         [30, 11, 80, ...,  0,  0,  0],
#         ...,
#         [ 5,  5,  0, ...,  0,  0,  0],
#         [ 6,  4,  4, ...,  0,  0,  0],
#         [ 4, 24,  0, ...,  0,  0,  0]])

# %%
model = lda.LDA(n_topics=50, n_iter=20)
model.fit(compressed_features)

# %%
n_top_words = 8
for i, topic_dist in enumerate(model.topic_word_):
    topic_words = np.array(vocab)[np.argsort(topic_dist)][:-n_top_words:-1]
    print('Topic {}: {}'.format(i, ' '.join(topic_words)))
# Out:
# Topic 0: Snhg11 Syt1 Map1b Olfm1 Rtn1 Ttc3 Kif1b
# Topic 1: Nrgn Rtn1 Syt1 Camk2b Basp1 Aplp1 Prkcb
# Topic 2: Cpe Prkcb Aplp1 Actg1 Chn1 Ttc3 Sub1
# Topic 3: Mef2c Camk2n1 Lars2 Syt1 Slc1a2 Atp2b2 2900097C17Rik
# Topic 4: Ttr Dbi Enpp2 Mt1 Rps29 Clu Cd9
# Topic 5: Rps29 Cox7c Actg1 Rplp1 Sub1 Lars2 Cox6b1
# Topic 6: Apod Qk Aplp1 Fos Kif1b Scd2 Sepp1
# Topic 7: Aldoa Hspa8 Rtn1 Atp6v0c-ps2 Actg1 Slc25a4 Atp6v1a
# Topic 8: Stmn3 Dynll1 Snca Chn1 Fkbp1a Tubb2a 3110035E14Rik
# Topic 9: Cox7c Rps29 Slc25a4 Ckb Cox6c Dynll1 Atp5c1
# Topic 10: Mdh1 Stmn2 Tpi1 Ndufa4 Eif4a2 Stmn3 Snca
# Topic 11: Gstp1 Taldo1 Prdx1 H3f3b Fau Srp14 Ptn
# Topic 12: Hpca Chn1 Itm2b Actg1 Ppp3ca Cpe Ywhaz
# Topic 13: Cox6b1 Mdh1 Cox8a Slc25a4 Cox7a2 Cox7c Cox6c
# Topic 14: D3Bwg0562e Gria1 Ppp3ca Tcf4 Camk2b Wfs1 Trim2
# Topic 15: Cst3 Rps29 Cox7c Ckb Cox4i1 Cox6b1 Slc25a4
# Topic 16: Dcn Itm2b Dynll1 Sub1 Slc25a4 Rps29 Actg1
# Topic 17: Dynll1 Scg5 Usmg5 Cox7c Cox8a Pcsk2 Chn1
# Topic 18: Mdh1 Tpi1 Tubb2a Eif4a2 Zwint Stmn2 Usmg5
# Topic 19: Hpca Ppp3ca Neurod6 Crym Prnp Prkcb Tspan13
# Topic 20: Aldoa Stmn3 Snca Nsf Hspa8 Gap43 Stmn2
# Topic 21: Pcp4 Mdh1 Tagln3 Pcsk2 Ndufa4 Ncald Aldoa
# Topic 22: Xist Jun Fos Eef1a1 Qk Ptma Ubc
# Topic 23: Ptgds Car2 Apod Gstp1 Cryab Fabp5 Dbi
# Topic 24: Usmg5 Scg5 Cox7c Rps29 Mdh1 Cox6c Rplp1
# Topic 25: Cst3 Apoe Rps29 Ftl1 Sepp1 Ccl7 Lyz2
# Topic 26: Chn1 Dynll1 Stmn3 3110035E14Rik Snca Slc25a4 Pde1a
# Topic 27: Rps29 H3f3b Cox8a Cox7c Cox6c Tecr Syt11
# Topic 28: Cnp Mog Mbp Mobp Scd2 Ugt8a Tspan2
# Topic 29: Hbb-bs Itm2a Sparc Hba-a2_loc2 Hba-a2_loc1 Ly6c1 Bsg
# Topic 30: Rps29 Rplp1 Rplp2 Dynll1 Sub1 Fau Rps28
# Topic 31: Ppp3ca Cpe Prkcb Slc8a1 Tspan13 Rtn1 Prnp
# Topic 32: Nrgn Basp1 Syt1 2900097C17Rik Prkcb Rtn1 3110035E14Rik
# Topic 33: Nrgn Ppp3ca Npcd Snhg11 Prkcb Olfm1 Rtn1
# Topic 34: Chn1 Pcsk2 Scg5 Usmg5 Ntm Prkcb Cox8a
# Topic 35: Itm2b Aldoa Xist Cox8a Sub1 Actg1 Amd2
# Topic 36: Snhg11 Prkcb Kcnq1ot1 Camk2a Ppp3ca Kif1b Ttc3
# Topic 37: Syt1 Camk2n1 Ndrg4 Rtn1 Map1b Ttc3 2900097C17Rik
# Topic 38: Camk2n1 Nrgn Rgs4 Arpp21 Olfm1 Chn1 Mef2c
# Topic 39: Sst Npy Mdh1 Scg5 Ndufa4 Stmn3 Zwint
# Topic 40: Aldoa Atp6v0c-ps2 Cpe Celf4 2900097C17Rik Atp6v1a Ywhaz
# Topic 41: Itm2b Ywhaz Snhg11 Calm3 Rtn1 Actg1 Pja2
# Topic 42: Tubb2a Cpe Aldoa Sub1 Chn1 Rtn1 Actg1
# Topic 43: Snhg11 Nnat Rtn1 Ttc3 Cpe Prnp Syt1
# Topic 44: Mdh1 Cox7a2 Ndufa4 Scg5 Atpif1 Usmg5 Cox4i1
# Topic 45: Mbp Nfasc Mag Cd81 Sirt2 Cnp Ctsl
# Topic 46: Cst3 Sparcl1 Slc1a2 Atp1a2 Apoe Mt1 Cpe
# Topic 47: Cnr1 Vip Htr3a Syt1 Gad1 Gad2 Nap1l5
# Topic 48: Acta2 Sparcl1 Myl6 Crip1 Myl9 Tagln Tpm1
# Topic 49: Apod Enpp2 Mog Ermn Mbp Ugt8a Car2

# %%
# This gives you a distribution over words (genes) for each topic. Each row sums to 1.
model.topic_word_

# These gives you a distribution over topics for each doc (sample)
#     This can serve as a dimensionality reduction!
model.doc_topic_
# Out:
# array([[  2.41509219e-02,   5.82795822e-03,   5.70808836e-06, ...,
#           1.51892231e-02,   6.74753125e-02,   1.35909584e-02],
#        [  8.67887508e-02,   1.57518740e-02,   2.47019168e-03, ...,
#           4.79956734e-01,   1.91678825e-03,   3.22483272e-03],
#        [  5.99940111e-02,   2.25632580e-02,   7.94031043e-03, ...,
#           4.38094525e-01,   9.58726356e-03,   2.04621450e-04],
#        ...,
#        [  8.83954755e-03,   4.18935903e-05,   4.18935903e-05, ...,
#           4.60829493e-04,   3.18852116e-01,   4.18935903e-05],
#        [  3.53370295e-02,   1.14093960e-02,   3.53078494e-03, ...,
#           2.91800409e-05,   2.42223519e-01,   2.91800409e-05],
#        [  3.95882819e-05,   3.60253365e-03,   3.95882819e-05, ...,
#           3.95882819e-05,   3.29809976e-01,   3.95882819e-05]])

# %%
document_distribution = pd.DataFrame(model.doc_topic_, index=features.index)
corresponding_classifications = classification[document_distribution.index]

# %%
from sklearn.cross_validation import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
# get a test set from 10 percent of the data.
doc_train, doc_test, class_train, class_test = train_test_split(document_distribution, corresponding_classifications, test_size=.1)

# %%
clf = SVC()
clf.fit(doc_train, class_train)
accuracy = accuracy_score(clf.predict(doc_test), class_test)
print accuracy
# Out:
# 0.720930232558

# %%
feat_classification = classification[features.index]
feat_train, feat_test, feat_class_train, feat_class_test = train_test_split(features, feat_classification, test_size=.1)

#clf_original = SVC()
#clf_original.fit(doc_train, class_train)

# %%
clf_orig_features = SVC()
clf_orig_features.fit(feat_train, feat_class_train)
accuracy_orig_features = accuracy_score(clf_orig_features.predict(feat_test), feat_class_test)
print accuracy_orig_features
# Out:
# 0.757475083056

# %%
#try the same thing after using PCA for dimensionality reduction.
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=20)
pca_features= pca.fit_transform(features)
pca_classification = classification[features.index]
pca_train, pca_test, pca_class_train, pca_class_test = train_test_split(pca_features, pca_classification, test_size=.1)
clf_pca_features = SVC()
clf_pca_features.fit(pca_train, pca_class_train)
accuracy_pca_features = accuracy_score(clf_pca_features.predict(pca_test), pca_class_test)
print accuracy_pca_features
# Out:
# 0.259136212625

# %%
# Do all of the above using LogisticRegression
from sklearn.linear_model import LogisticRegression
import sys

# %%
logistic_orig_features = LogisticRegression()
logistic_pca_features = LogisticRegression()
logistic_lda_features = LogisticRegression()

logistic_orig_features.fit(feat_train, feat_class_train)
logistic_pca_features.fit(pca_train, pca_class_train)
logistic_lda_features.fit(doc_train, class_train)

logistic_orig_accuracy = accuracy_score(logistic_orig_features.predict(feat_test), feat_class_test)
logistic_pca_accuracy = accuracy_score(logistic_pca_features.predict(pca_test), pca_class_test)
logistic_lda_accuracy = accuracy_score(logistic_lda_features.predict(doc_test), class_test)

print "Original Features Score", logistic_orig_accuracy
sys.stdout.flush()
print "PCA Features Score", logistic_pca_accuracy
sys.stdout.flush()
print "LDA Features Score", logistic_lda_accuracy
sys.stdout.flush()
# Out:
# Original Features Score 0.946843853821
# PCA Features Score 0.936877076412
# LDA Features Score 0.950166112957

# %%
compressed_features.shape
# Out:
# (3005, 12883)

# %%
numTopicsWanted = 4
ctm = CTMParallel(compressed_features.shape[0], numTopicsWanted, compressed_features.shape[1],compressed_features.todense(), 10, .001)

# %%
ctm.EM()

# %%
x1 = np.ones((19956, 4))
x2 = np.linspace(0, 19956, 19956 )

# %%
x1.shape
# Out:
# (19956, 4)

# %%
x2[:, np.newaxis].T.shape
# Out:
# (1, 19956)

# %%
np.multiply(x1,x2[:, np.newaxis])
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  1.00005011e+00,   1.00005011e+00,   1.00005011e+00,
#           1.00005011e+00],
#        [  2.00010023e+00,   2.00010023e+00,   2.00010023e+00,
#           2.00010023e+00],
#        ...,
#        [  1.99539999e+04,   1.99539999e+04,   1.99539999e+04,
#           1.99539999e+04],
#        [  1.99549999e+04,   1.99549999e+04,   1.99549999e+04,
#           1.99549999e+04],
#        [  1.99560000e+04,   1.99560000e+04,   1.99560000e+04,
#           1.99560000e+04]])

# %% [markdown]
# # This part does the work above with the rat data.

# %%
data = pd.read_csv('counts_rat.csv').set_index('GeneID')
genes_wanted = (data > 1).sum(axis=1) > 5
genes_wanted = data.var(axis=1).sort(inplace=False, ascending=False)[:2000].index
counts_newsetup = data.ix[genes_wanted, :].T
classes = np.array(map(lambda x: x.split("_")[0], counts_newsetup.index))
vocab = counts_newsetup.columns
counts = counts_newsetup.values

# %%
model = lda.LDA(n_topics=10, n_iter=20)
model.fit(counts)

# %%
doc_train, doc_test, class_train, class_test = train_test_split(model.doc_topic_, classes, test_size=.2)

# %%
clf = LogisticRegression()
clf.fit(doc_train, class_train)
accuracy = accuracy_score(clf.predict(doc_test), class_test)
print accuracy
